# %%
# NOTE: please read the README file to correctly utilize the script for 
# data cleaning usage!
import yfinance as yf
import pandas as pd
import os
import glob

# %%
df = pd.read_csv("./_exchange_rate_against_usd.csv")
df
# Out:
#       Currency       AUD       CAD       CHF       CNY       GBP       HKD  \
# 0       1/3/49       NaN       NaN       NaN       NaN       NaN       NaN
# 1       1/4/49       NaN       NaN       NaN       NaN       NaN       NaN
# 2       1/5/49       NaN       NaN       NaN       NaN       NaN       NaN
# 3       1/6/49       NaN       NaN       NaN       NaN       NaN       NaN
# 4       1/7/49       NaN       NaN       NaN       NaN       NaN       NaN
# ...        ...       ...       ...       ...       ...       ...       ...
# 26827  6/16/22  1.436442  1.292885  0.975192  6.715769  0.822596  7.849808
# 26828  6/17/22  1.434198  1.299924  0.963666  6.704940  0.815373  7.849895
# 26829  6/18/22       NaN       NaN       NaN       NaN       NaN       NaN
# 26830  6/19/22       NaN       NaN       NaN       NaN       NaN       NaN
# 26831  6/20/22  1.432062  1.299040  0.966245  6.688790  0.815328  7.849957
#
# ...

# %%
# final used for cleaning: df_3
df_3 = df.dropna()
df_3

col_name= [] # store currency name
df_3.reset_index()

for i in df_3.columns:
    col_name.append(i)

# %%
# NOTE: remember to manually delete the ./separated/USD.csv manually! 
# we don't need that file in final merging. After run this cell, go 
# to ./separated and run that script cell by cell!

# separate & store each currency into separate csv
count = 1
while(count < 18):
    headers = ["Currency","%s" % (col_name[count])]
    #df_3.to_csv('./separated/%s.csv' % (col_name[count]), columns=headers,index=None)
    df_3.to_csv('./separated/%s.csv' %
                (col_name[count]), columns=headers, index=None)
    count += 1
